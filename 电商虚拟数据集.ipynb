# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random

def generate_comprehensive_ecommerce_data():
    """生成完善的电商模拟数据"""
    
    # 设置随机种子保证可重复性
    np.random.seed(42)
    random.seed(42)
    
    # 1. 用户维度表 - 增加用户画像相关字段
    n_customers = 5000
    customers = pd.DataFrame({
        'customer_id': range(1, n_customers + 1),
        'customer_name': [f'User_{i}' for i in range(1, n_customers + 1)],
        'gender': np.random.choice(['Male', 'Female'], n_customers, p=[0.48, 0.52]),
        'birth_year': np.random.randint(1970, 2005, n_customers),
        'registration_date': pd.to_datetime([datetime(2020,1,1) + timedelta(days=np.random.randint(0, 1460)) for _ in range(n_customers)]),
        'email': [f'user{i}@example.com' for i in range(1, n_customers + 1)],
        'phone': [f'1{np.random.randint(300,999):03d}{np.random.randint(1000,9999):04d}' for _ in range(n_customers)],
        'country': np.random.choice(['USA', 'Canada', 'UK', 'Australia'], n_customers, p=[0.6, 0.2, 0.15, 0.05]),
        'city': np.random.choice(['New York', 'Los Angeles', 'Chicago', 'Toronto', 'London', 'Sydney'], n_customers),
        'zip_code': [f'{np.random.randint(10000, 99999)}' for _ in range(n_customers)],
        'registration_channel': np.random.choice(['Web', 'Mobile App', 'Social Media', 'Referral'], n_customers, p=[0.4, 0.35, 0.15, 0.1]),
        'loyalty_tier': np.random.choice(['Bronze', 'Silver', 'Gold', 'Platinum'], n_customers, p=[0.5, 0.3, 0.15, 0.05]),
        'preferred_category': np.random.choice(['Electronics', 'Clothing', 'Home', 'Books', 'Sports'], n_customers),
        'avg_order_value_segment': np.random.choice(['Low', 'Medium', 'High'], n_customers, p=[0.6, 0.3, 0.1]),
        'last_login_date': None,
        'total_orders': 0,
        'total_spent': 0.0
    })
    
    # 2. 商品维度表
    n_products = 200
    categories = {
        'Electronics': ['Smartphone', 'Laptop', 'Tablet', 'Headphones', 'Smartwatch'],
        'Clothing': ['T-Shirt', 'Jeans', 'Dress', 'Jacket', 'Shoes'],
        'Home': ['Furniture', 'Kitchenware', 'Decor', 'Lighting', 'Bedding'],
        'Books': ['Fiction', 'Non-Fiction', 'Academic', 'Children', 'Cookbook'],
        'Sports': ['Equipment', 'Apparel', 'Footwear', 'Accessories']
    }
    
    products_data = []
    product_id = 1
    for category, subcategories in categories.items():
        for subcategory in subcategories:
            for i in range(n_products // (len(categories) * len(subcategories))):
                products_data.append({
                    'product_id': product_id,
                    'product_name': f'{subcategory} Model {product_id}',
                    'category': category,
                    'subcategory': subcategory,
                    'brand': np.random.choice(['BrandA', 'BrandB', 'BrandC', 'BrandD', 'BrandE']),
                    'price': round(np.random.uniform(10, 500), 2),
                    'cost_price': round(np.random.uniform(5, 300), 2),
                    'stock_quantity': np.random.randint(0, 1000),
                    'supplier': f'Supplier_{np.random.randint(1, 20)}',
                    'rating': round(np.random.uniform(3.0, 5.0), 1),
                    'review_count': np.random.randint(0, 500),
                    'created_date': pd.to_datetime(datetime(2021,1,1) + timedelta(days=np.random.randint(0, 1000))),
                    'is_active': np.random.choice([True, False], p=[0.9, 0.1])
                })
                product_id += 1
    
    products = pd.DataFrame(products_data)
    
    # 3. 时间维度表
    dates = pd.date_range('2022-01-01', '2024-12-31', freq='D')
    time_dim = pd.DataFrame({
        'date': dates,
        'day': dates.day,
        'month': dates.month,
        'month_name': dates.strftime('%B'),
        'quarter': dates.quarter,
        'year': dates.year,
        'day_of_week': dates.dayofweek,
        'day_name': dates.strftime('%A'),
        'is_weekend': (dates.dayofweek >= 5).astype(int),
        'is_holiday': np.random.choice([0, 1], len(dates), p=[0.9, 0.1])
    })
    
    # 4. 地区维度表
    regions = pd.DataFrame({
        'region_id': range(1, 7),
        'region_name': ['North America', 'Europe', 'Asia Pacific', 'South America', 'Africa', 'Middle East'],
        'region_manager': ['Manager_A', 'Manager_B', 'Manager_C', 'Manager_D', 'Manager_E', 'Manager_F']
    })
    
    # 5. 订单事实表 (包含用户行为数据)
    n_orders = 50000
    orders_data = []
    
    for i in range(n_orders):
        customer_id = np.random.randint(1, n_customers + 1)
        product_id = np.random.randint(1, len(products) + 1)
        order_date = pd.to_datetime(datetime(2023,1,1) + timedelta(days=np.random.randint(0, 730)))
        quantity = np.random.randint(1, 6)
        price = products.loc[products['product_id'] == product_id, 'price'].values[0]
        amount = quantity * price
        
        # 模拟用户行为数据
        browsing_duration = np.random.randint(10, 1800)  # 浏览时长(秒)
        click_count = np.random.randint(1, 20)
        
        orders_data.append({
            'order_id': i + 1,
            'customer_id': customer_id,
            'product_id': product_id,
            'order_date': order_date,
            'quantity': quantity,
            'unit_price': price,
            'amount': amount,
            'region_id': np.random.randint(1, 7),
            'payment_method': np.random.choice(['Credit Card', 'PayPal', 'Apple Pay', 'Google Pay']),
            'shipping_method': np.random.choice(['Standard', 'Express', 'Next Day']),
            'order_status': np.random.choice(['Completed', 'Shipped', 'Processing', 'Cancelled'], p=[0.7, 0.15, 0.1, 0.05]),
            'browsing_duration_seconds': browsing_duration,
            'click_count': click_count,
            'add_to_cart_count': np.random.randint(0, 5),
            'wishlist_added': np.random.choice([0, 1], p=[0.7, 0.3]),
            'discount_applied': round(np.random.uniform(0, 0.3), 2),
            'customer_rating': np.random.choice([1, 2, 3, 4, 5], p=[0.05, 0.1, 0.2, 0.4, 0.25]),
            'return_requested': np.random.choice([0, 1], p=[0.95, 0.05])
        })
    
    orders = pd.DataFrame(orders_data)
    
    # 6. 更新用户表中的聚合信息 - 修复部分
    customer_stats = orders.groupby('customer_id').agg({
        'order_id': 'count',
        'amount': 'sum',
        'order_date': 'max'
    }).reset_index()
    
    customer_stats.columns = ['customer_id', 'total_orders_new', 'total_spent_new', 'last_order_date']
    
    # 合并时使用suffixes参数避免列名冲突
    customers = customers.merge(customer_stats, on='customer_id', how='left')
    
    # 更新统计信息
    customers['total_orders'] = customers['total_orders_new'].fillna(0)
    customers['total_spent'] = customers['total_spent_new'].fillna(0.0)
    customers['last_login_date'] = customers['last_order_date']  # 简化处理
    
    # 删除临时列
    customers = customers.drop(['total_orders_new', 'total_spent_new'], axis=1)
    
    # 7. 用户行为日志表 (用于推荐算法)
    n_behavior_logs = 100000
    behavior_logs = pd.DataFrame({
        'log_id': range(1, n_behavior_logs + 1),
        'customer_id': np.random.randint(1, n_customers + 1, n_behavior_logs),
        'product_id': np.random.randint(1, len(products) + 1, n_behavior_logs),
        'behavior_type': np.random.choice(['view', 'click', 'add_to_cart', 'purchase', 'wishlist'], 
                                        n_behavior_logs, p=[0.4, 0.3, 0.15, 0.1, 0.05]),
        'timestamp': pd.to_datetime([datetime(2024,1,1) + timedelta(seconds=np.random.randint(0, 31536000)) 
                                   for _ in range(n_behavior_logs)]),
        'session_id': [f'session_{np.random.randint(1, 10000)}' for _ in range(n_behavior_logs)],
        'device_type': np.random.choice(['Desktop', 'Mobile', 'Tablet'], n_behavior_logs),
        'browser': np.random.choice(['Chrome', 'Safari', 'Firefox', 'Edge'], n_behavior_logs)
    })
    
    return {
        'customers': customers,
        'products': products,
        'time_dim': time_dim,
        'regions': regions,
        'orders': orders,
        'behavior_logs': behavior_logs
    }

# 生成数据
data_dict = generate_comprehensive_ecommerce_data()

# 验证数据生成成功
print("数据生成成功！")
for table_name, table_data in data_dict.items():
    print(f"{table_name}: {len(table_data)} 行")
# Out:
# 数据生成成功！
# customers: 5000 行
# products: 200 行
# time_dim: 1096 行
# regions: 6 行
# orders: 50000 行
# behavior_logs: 100000 行

# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl.metadata (4.3 kB)
# Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random
from sqlalchemy import create_engine, text
import pymysql

def create_database_connection():
    """创建数据库连接"""
    db_config = {
        'host': 'localhost',
        'port': 628,
        'user': 'root',  # 替换为你的用户名
        'password': '021015',  # 替换为你的密码
        'database': 'ecommerce_portfolio'
    }
    
    try:
        engine = create_engine(
            f"mysql+pymysql://{db_config['user']}:{db_config['password']}@{db_config['host']}:{db_config['port']}/{db_config['database']}"
        )
        # 测试连接
        with engine.connect() as conn:
            print("✅ 数据库连接成功!")
        return engine
    except Exception as e:
        print(f"❌ 数据库连接失败: {e}")
        return None

def import_data_to_mysql(data_dict, engine):
    """将数据导入MySQL数据库"""
    
    # 定义导入顺序（先维度表，后事实表）
    import_order = ['regions', 'time_dim', 'products', 'customers', 'orders', 'behavior_logs']
    
    for table_name in import_order:
        if table_name in data_dict:
            df = data_dict[table_name]
            try:
                # 导入数据
                df.to_sql(
                    name=table_name,
                    con=engine,
                    if_exists='append',  # 追加到现有表
                    index=False,
                    method='multi',
                    chunksize=1000
                )
                print(f"✅ 成功导入表: {table_name}, 数据量: {len(df)}")
            except Exception as e:
                print(f"❌ 导入表 {table_name} 失败: {e}")

def generate_comprehensive_ecommerce_data():
    """生成完善的电商模拟数据 - 修复版本"""
    
    # 设置随机种子保证可重复性
    np.random.seed(42)
    random.seed(42)
    
    # 1. 用户维度表 - 修复字段匹配问题
    n_customers = 5000
    customers = pd.DataFrame({
        'customer_id': range(1, n_customers + 1),
        'customer_name': [f'User_{i}' for i in range(1, n_customers + 1)],
        'gender': np.random.choice(['Male', 'Female'], n_customers, p=[0.48, 0.52]),
        'birth_year': np.random.randint(1970, 2005, n_customers),
        'registration_date': pd.to_datetime([datetime(2020,1,1) + timedelta(days=np.random.randint(0, 1460)) for _ in range(n_customers)]),
        'email': [f'user{i}@example.com' for i in range(1, n_customers + 1)],
        'phone': [f'1{np.random.randint(300,999):03d}{np.random.randint(1000,9999):04d}' for _ in range(n_customers)],
        'country': np.random.choice(['USA', 'Canada', 'UK', 'Australia'], n_customers, p=[0.6, 0.2, 0.15, 0.05]),
        'city': np.random.choice(['New York', 'Los Angeles', 'Chicago', 'Toronto', 'London', 'Sydney'], n_customers),
        'zip_code': [f'{np.random.randint(10000, 99999)}' for _ in range(n_customers)],
        'registration_channel': np.random.choice(['Web', 'Mobile App', 'Social Media', 'Referral'], n_customers, p=[0.4, 0.35, 0.15, 0.1]),
        'loyalty_tier': np.random.choice(['Bronze', 'Silver', 'Gold', 'Platinum'], n_customers, p=[0.5, 0.3, 0.15, 0.05]),
        'preferred_category': np.random.choice(['Electronics', 'Clothing', 'Home', 'Books', 'Sports'], n_customers),
        'avg_order_value_segment': np.random.choice(['Low', 'Medium', 'High'], n_customers, p=[0.6, 0.3, 0.1]),
        'last_login_date': None,  # 初始化为None，后面更新
        'total_orders': 0,
        'total_spent': 0.0
    })
    
    # 2. 商品维度表
    n_products = 200
    categories = {
        'Electronics': ['Smartphone', 'Laptop', 'Tablet', 'Headphones', 'Smartwatch'],
        'Clothing': ['T-Shirt', 'Jeans', 'Dress', 'Jacket', 'Shoes'],
        'Home': ['Furniture', 'Kitchenware', 'Decor', 'Lighting', 'Bedding'],
        'Books': ['Fiction', 'Non-Fiction', 'Academic', 'Children', 'Cookbook'],
        'Sports': ['Equipment', 'Apparel', 'Footwear', 'Accessories']
    }
    
    products_data = []
    product_id = 1
    for category, subcategories in categories.items():
        for subcategory in subcategories:
            for i in range(n_products // (len(categories) * len(subcategories))):
                products_data.append({
                    'product_id': product_id,
                    'product_name': f'{subcategory} Model {product_id}',
                    'category': category,
                    'subcategory': subcategory,
                    'brand': np.random.choice(['BrandA', 'BrandB', 'BrandC', 'BrandD', 'BrandE']),
                    'price': round(np.random.uniform(10, 500), 2),
                    'cost_price': round(np.random.uniform(5, 300), 2),
                    'stock_quantity': np.random.randint(0, 1000),
                    'supplier': f'Supplier_{np.random.randint(1, 20)}',
                    'rating': round(np.random.uniform(3.0, 5.0), 1),
                    'review_count': np.random.randint(0, 500),
                    'created_date': pd.to_datetime(datetime(2021,1,1) + timedelta(days=np.random.randint(0, 1000))),
                    'is_active': np.random.choice([True, False], p=[0.9, 0.1])
                })
                product_id += 1
    
    products = pd.DataFrame(products_data)
    
    # 3. 时间维度表
    dates = pd.date_range('2022-01-01', '2024-12-31', freq='D')
    time_dim = pd.DataFrame({
        'date': dates,
        'day': dates.day,
        'month': dates.month,
        'month_name': dates.strftime('%B'),
        'quarter': dates.quarter,
        'year': dates.year,
        'day_of_week': dates.dayofweek,
        'day_name': dates.strftime('%A'),
        'is_weekend': (dates.dayofweek >= 5).astype(int),
        'is_holiday': np.random.choice([0, 1], len(dates), p=[0.9, 0.1])
    })
    
    # 4. 地区维度表
    regions = pd.DataFrame({
        'region_id': range(1, 7),
        'region_name': ['North America', 'Europe', 'Asia Pacific', 'South America', 'Africa', 'Middle East'],
        'region_manager': ['Manager_A', 'Manager_B', 'Manager_C', 'Manager_D', 'Manager_E', 'Manager_F']
    })
    
    # 5. 订单事实表 (包含用户行为数据)
    n_orders = 50000
    orders_data = []
    
    for i in range(n_orders):
        customer_id = np.random.randint(1, n_customers + 1)
        product_id = np.random.randint(1, len(products) + 1)
        order_date = pd.to_datetime(datetime(2023,1,1) + timedelta(days=np.random.randint(0, 730)))
        quantity = np.random.randint(1, 6)
        price = products.loc[products['product_id'] == product_id, 'price'].values[0]
        amount = quantity * price
        
        # 模拟用户行为数据
        browsing_duration = np.random.randint(10, 1800)  # 浏览时长(秒)
        click_count = np.random.randint(1, 20)
        
        orders_data.append({
            'order_id': i + 1,
            'customer_id': customer_id,
            'product_id': product_id,
            'order_date': order_date,
            'quantity': quantity,
            'unit_price': price,
            'amount': amount,
            'region_id': np.random.randint(1, 7),
            'payment_method': np.random.choice(['Credit Card', 'PayPal', 'Apple Pay', 'Google Pay']),
            'shipping_method': np.random.choice(['Standard', 'Express', 'Next Day']),
            'order_status': np.random.choice(['Completed', 'Shipped', 'Processing', 'Cancelled'], p=[0.7, 0.15, 0.1, 0.05]),
            'browsing_duration_seconds': browsing_duration,
            'click_count': click_count,
            'add_to_cart_count': np.random.randint(0, 5),
            'wishlist_added': np.random.choice([0, 1], p=[0.7, 0.3]),
            'discount_applied': round(np.random.uniform(0, 0.3), 2),
            'customer_rating': np.random.choice([1, 2, 3, 4, 5], p=[0.05, 0.1, 0.2, 0.4, 0.25]),
            'return_requested': np.random.choice([0, 1], p=[0.95, 0.05])
        })
    
    orders = pd.DataFrame(orders_data)
    
    # 6. 更新用户表中的聚合信息 - 修复版本
    customer_stats = orders.groupby('customer_id').agg({
        'order_id': 'count',
        'amount': 'sum',
        'order_date': 'max'
    }).reset_index()
    
    customer_stats.columns = ['customer_id', 'total_orders_new', 'total_spent_new', 'last_order_date']
    
    # 合并统计信息
    customers = customers.merge(customer_stats, on='customer_id', how='left')
    
    # 更新统计信息 - 只更新MySQL表中存在的字段
    customers['total_orders'] = customers['total_orders_new'].fillna(0).astype(int)
    customers['total_spent'] = customers['total_spent_new'].fillna(0.0)
    customers['last_login_date'] = customers['last_order_date']  # 使用last_order_date更新last_login_date
    
    # 删除临时列，只保留MySQL表中存在的字段
    customers = customers.drop(['total_orders_new', 'total_spent_new', 'last_order_date'], axis=1)
    
    # 7. 用户行为日志表 (用于推荐算法)
    n_behavior_logs = 100000
    behavior_logs = pd.DataFrame({
        'log_id': range(1, n_behavior_logs + 1),
        'customer_id': np.random.randint(1, n_customers + 1, n_behavior_logs),
        'product_id': np.random.randint(1, len(products) + 1, n_behavior_logs),
        'behavior_type': np.random.choice(['view', 'click', 'add_to_cart', 'purchase', 'wishlist'], 
                                        n_behavior_logs, p=[0.4, 0.3, 0.15, 0.1, 0.05]),
        'timestamp': pd.to_datetime([datetime(2024,1,1) + timedelta(seconds=np.random.randint(0, 31536000)) 
                                   for _ in range(n_behavior_logs)]),
        'session_id': [f'session_{np.random.randint(1, 10000)}' for _ in range(n_behavior_logs)],
        'device_type': np.random.choice(['Desktop', 'Mobile', 'Tablet'], n_behavior_logs),
        'browser': np.random.choice(['Chrome', 'Safari', 'Firefox', 'Edge'], n_behavior_logs)
    })
    
    return {
        'customers': customers,
        'products': products,
        'time_dim': time_dim,
        'regions': regions,
        'orders': orders,
        'behavior_logs': behavior_logs
    }

def generate_and_import_data():
    """生成数据并导入到MySQL"""
    
    print("开始生成模拟数据...")
    data_dict = generate_comprehensive_ecommerce_data()
    
    # 验证数据列与MySQL表匹配
    print("\n验证数据列结构:")
    for table_name, df in data_dict.items():
        print(f"{table_name} 列: {list(df.columns)}")
    
    print("\n连接数据库...")
    engine = create_database_connection()
    
    if engine:
        print("开始导入数据到MySQL...")
        import_data_to_mysql(data_dict, engine)
        print("🎉 数据导入完成!")
    else:
        print("无法连接数据库，请检查配置")

# 执行数据生成和导入
if __name__ == "__main__":
    generate_and_import_data()
# Out:
# 开始生成模拟数据...
#
# 验证数据列结构:
# customers 列: ['customer_id', 'customer_name', 'gender', 'birth_year', 'registration_date', 'email', 'phone', 'country', 'city', 'zip_code', 'registration_channel', 'loyalty_tier', 'preferred_category', 'avg_order_value_segment', 'last_login_date', 'total_orders', 'total_spent']
# products 列: ['product_id', 'product_name', 'category', 'subcategory', 'brand', 'price', 'cost_price', 'stock_quantity', 'supplier', 'rating', 'review_count', 'created_date', 'is_active']
# time_dim 列: ['date', 'day', 'month', 'month_name', 'quarter', 'year', 'day_of_week', 'day_name', 'is_weekend', 'is_holiday']
# regions 列: ['region_id', 'region_name', 'region_manager']
# orders 列: ['order_id', 'customer_id', 'product_id', 'order_date', 'quantity', 'unit_price', 'amount', 'region_id', 'payment_method', 'shipping_method', 'order_status', 'browsing_duration_seconds', 'click_count', 'add_to_cart_count', 'wishlist_added', 'discount_applied', 'customer_rating', 'return_requested']
# behavior_logs 列: ['log_id', 'customer_id', 'product_id', 'behavior_type', 'timestamp', 'session_id', 'device_type', 'browser']
#
# 连接数据库...
# ✅ 数据库连接成功!
# 开始导入数据到MySQL...
# ❌ 导入表 regions 失败: (pymysql.err.IntegrityError) (1062, "Duplicate entry '1' for key 'regions.PRIMARY'")
# [SQL: INSERT INTO regions (region_id, region_name, region_manager) VALUES (%(region_id_m0)s, %(region_name_m0)s, %(region_manager_m0)s), (%(region_id_m1)s, %(region_name_m1)s, %(region_manager_m1)s), (%(region_id_m2)s, %(region_name_m2)s, %(region_manager_m2)s), (%(region_id_m3)s, %(region_name_m3)s, %(region_manager_m3)s), (%(region_id_m4)s, %(region_name_m4)s, %(region_manager_m4)s), (%(region_id_m5)s, %(region_name_m5)s, %(region_manager_m5)s)]
# [parameters: {'region_id_m0': 1, 'region_name_m0': 'North America', 'region_manager_m0': 'Manager_A', 'region_id_m1': 2, 'region_name_m1': 'Europe', 'region_manager_m1': 'Manager_B', 'region_id_m2': 3, 'region_name_m2': 'Asia Pacific', 'region_manager_m2': 'Manager_C', 'region_id_m3': 4, 'region_name_m3': 'South America', 'region_manager_m3': 'Manager_D', 'region_id_m4': 5, 'region_name_m4': 'Africa', 'region_manager_m4': 'Manager_E', 'region_id_m5': 6, 'region_name_m5': 'Middle East', 'region_manager_m5': 'Manager_F'}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ 导入表 time_dim 失败: (pymysql.err.IntegrityError) (1062, "Duplicate entry '2022-01-01' for key 'time_dim.date'")
# [SQL: INSERT INTO time_dim (date, day, month, month_name, quarter, year, day_of_week, day_name, is_weekend, is_holiday) VALUES (%(date_m0)s, %(day_m0)s, %(month_m0)s, %(month_name_m0)s, %(quarter_m0)s, %(year_m0)s, %(day_of_week_m0)s, %(day_name_m0)s, %(is_weekend_m0)s, %(is_holiday_m0)s), (%(date_m1)s, %(day_m1)s, %(month_m1)s, %(month_name_m1)s, %(quarter_m1)s, %(year_m1)s, %(day_of_week_m1)s, %(day_name_m1)s, %(is_weekend_m1)s, %(is_holiday_m1)s), (%(date_m2)s, %(day_m2)s, %(month_m2)s, %(month_name_m2)s, %(quarter_m2)s, %(year_m2)s, %(day_of_week_m2)s, %(day_name_m2)s, %(is_weekend_m2)s, %(is_holiday_m2)s), (%(date_m3)s, %(day_m3)s, %(month_m3)s, %(month_name_m3)s, %(quarter_m3)s, %(year_m3)s, %(day_of_week_m3)s, %(day_name_m3)s, %(is_weekend_m3)s, %(is_holiday_m3)s), (%(date_m4)s, %(day_m4)s, %(month_m4)s, %(month_name_m4)s, %(quarter_m4)s, %(year_m4)s, %(day_of_week_m4)s, %(day_name_m4)s, %(is_weekend_m4)s, %(is_holiday_m4)s), (%(date_m5)s, %(day_m5)s, %(month_m5)s, %(month_name_m5)s, %(quarter_m5)s, %(year_m5)s, %(day_of_week_m5)s, %(day_name_m5)s, %(is_weekend_m5)s, %(is_holiday_m5)s), (%(date_m6)s, %(day_m6)s, %(month_m6)s, %(month_name_m6)s, %(quarter_m6)s, %(year_m6)s, %(day_of_week_m6)s, %(day_name_m6)s, %(is_weekend_m6)s, %(is_holiday_m6)s), (%(date_m7)s, %(day_m7)s, %(month_m7)s, %(month_name_m7)s, %(quarter_m7)s, %(year_m7)s, %(day_of_week_m7)s, %(day_name_m7)s, %(is_weekend_m7)s, %(is_holiday_m7)s), (%(date_m8)s, %(day_m8)s, %(month_m8)s, %(month_name_m8)s, %(quarter_m8)s, %(year_m8)s, %(day_of_week_m8)s, %(day_name_m8)s, %(is_weekend_m8)s, %(is_holiday_m8)s), (%(date_m9)s, %(day_m9)s, %(month_m9)s, %(month_name_m9)s, %(quarter_m9)s, %(year_m9)s, %(day_of_week_m9)s, %(day_name_m9)s, %(is_weekend_m9)s, %(is_holiday_m9)s), (%(date_m10)s, %(day_m10)s, %(month_m10)s, %(month_name_m10)s, %(quarter_m10)s, %(year_m10)s, %(day_of_week_m10)s, %(day_name_m10)s, %(is_weekend_m10)s, %(is_holiday_m10)s), (%(date_m11)s, %(day_m11)s, %(month_m11)s, %(month_name_m11)s, %(quarter_m11)s, %(year_m11)s, %(day_of_week_m11)s, %(day_name_m11)s, %(is_weekend_m11)s, %(is_holiday_m11)s), (%(date_m12)s, %(day_m12)s, %(month_m12)s, %(month_name_m12)s, %(quarter_m12)s, %(year_m12)s, %(day_of_week_m12)s, %(day_name_m12)s, %(is_weekend_m12)s, %(is_holiday_m12)s), (%(date_m13)s, %(day_m13)s, %(month_m13)s, %(month_name_m13)s, %(quarter_m13)s, %(year_m13)s, %(day_of_week_m13)s, %(day_name_m13)s, %(is_weekend_m13)s, %(is_holiday_m13)s), (%(date_m14)s, %(day_m14)s, %(month_m14)s, %(month_name_m14)s, %(quarter_m14)s, %(year_m14)s, %(day_of_week_m14)s, %(day_name_m14)s, %(is_weekend_m14)s, %(is_holiday_m14)s), (%(date_m15)s, %(day_m15)s, %(month_m15)s, %(month_name_m15)s, %(quarter_m15)s, %(year_m15)s, %(day_of_week_m15)s, %(day_name_m15)s, %(is_weekend_m15)s, %(is_holiday_m15)s), (%(date_m16)s, %(day_m16)s, %(month_m16)s, %(month_name_m16)s, %(quarter_m16)s, %(year_m16)s, %(day_of_week_m16)s, %(day_name_m16)s, %(is_weekend_m16)s, %(is_holiday_m16)s), (%(date_m17)s, %(day_m17)s, %(month_m17)s, %(month_name_m17)s, %(quarter_m17)s, %(year_m17)s, %(day_of_week_m17)s, %(day_name_m17)s, %(is_weekend_m17)s, %(is_holiday_m17)s), (%(date_m18)s, %(day_m18)s, %(month_m18)s, %(month_name_m18)s, %(quarter_m18)s, %(year_m18)s, %(day_of_week_m18)s, %(day_name_m18)s, %(is_weekend_m18)s, %(is_holiday_m18)s), (%(date_m19)s, %(day_m19)s, %(month_m19)s, %(month_name_m19)s, %(quarter_m19)s, %(year_m19)s, %(day_of_week_m19)s, %(day_name_m19)s, %(is_weekend_m19)s, %(is_holiday_m19)s), (%(date_m20)s, %(day_m20)s, %(month_m20)s, %(month_name_m20)s, %(quarter_m20)s, %(year_m20)s, %(day_of_week_m20)s, %(day_name_m20)s, %(is_weekend_m20)s, %(is_holiday_m20)s), (%(date_m21)s, %(day_m21)s, %(month_m21)s, %(month_name_m21)s, %(quarter_m21)s, %(year_m21)s, %(day_of_week_m21)s, %(day_name_m21)s, %(is_weekend_m21)s, %(is_holiday_m21)s), (%(date_m22)s, %(day_m22)s, %(month_m22)s, %(month_name_m22)s, %(quarter_m22)s, %(year_m22)s, %(day_of_week_m22)s, %(day_name_m22)s, %(is_weekend ...
# [parameters: {'date_m0': datetime.datetime(2022, 1, 1, 0, 0), 'day_m0': 1, 'month_m0': 1, 'month_name_m0': 'January', 'quarter_m0': 1, 'year_m0': 2022, 'day_of_week_m0': 5, 'day_name_m0': 'Saturday', 'is_weekend_m0': 1, 'is_holiday_m0': 0, 'date_m1': datetime.datetime(2022, 1, 2, 0, 0), 'day_m1': 2, 'month_m1': 1, 'month_name_m1': 'January', 'quarter_m1': 1, 'year_m1': 2022, 'day_of_week_m1': 6, 'day_name_m1': 'Sunday', 'is_weekend_m1': 1, 'is_holiday_m1': 0, 'date_m2': datetime.datetime(2022, 1, 3, 0, 0), 'day_m2': 3, 'month_m2': 1, 'month_name_m2': 'January', 'quarter_m2': 1, 'year_m2': 2022, 'day_of_week_m2': 0, 'day_name_m2': 'Monday', 'is_weekend_m2': 0, 'is_holiday_m2': 1, 'date_m3': datetime.datetime(2022, 1, 4, 0, 0), 'day_m3': 4, 'month_m3': 1, 'month_name_m3': 'January', 'quarter_m3': 1, 'year_m3': 2022, 'day_of_week_m3': 1, 'day_name_m3': 'Tuesday', 'is_weekend_m3': 0, 'is_holiday_m3': 0, 'date_m4': datetime.datetime(2022, 1, 5, 0, 0), 'day_m4': 5, 'month_m4': 1, 'month_name_m4': 'January', 'quarter_m4': 1, 'year_m4': 2022, 'day_of_week_m4': 2, 'day_name_m4': 'Wednesday', 'is_weekend_m4': 0, 'is_holiday_m4': 0 ... 9900 parameters truncated ... 'date_m995': datetime.datetime(2024, 9, 22, 0, 0), 'day_m995': 22, 'month_m995': 9, 'month_name_m995': 'September', 'quarter_m995': 3, 'year_m995': 2024, 'day_of_week_m995': 6, 'day_name_m995': 'Sunday', 'is_weekend_m995': 1, 'is_holiday_m995': 0, 'date_m996': datetime.datetime(2024, 9, 23, 0, 0), 'day_m996': 23, 'month_m996': 9, 'month_name_m996': 'September', 'quarter_m996': 3, 'year_m996': 2024, 'day_of_week_m996': 0, 'day_name_m996': 'Monday', 'is_weekend_m996': 0, 'is_holiday_m996': 0, 'date_m997': datetime.datetime(2024, 9, 24, 0, 0), 'day_m997': 24, 'month_m997': 9, 'month_name_m997': 'September', 'quarter_m997': 3, 'year_m997': 2024, 'day_of_week_m997': 1, 'day_name_m997': 'Tuesday', 'is_weekend_m997': 0, 'is_holiday_m997': 0, 'date_m998': datetime.datetime(2024, 9, 25, 0, 0), 'day_m998': 25, 'month_m998': 9, 'month_name_m998': 'September', 'quarter_m998': 3, 'year_m998': 2024, 'day_of_week_m998': 2, 'day_name_m998': 'Wednesday', 'is_weekend_m998': 0, 'is_holiday_m998': 0, 'date_m999': datetime.datetime(2024, 9, 26, 0, 0), 'day_m999': 26, 'month_m999': 9, 'month_name_m999': 'September', 'quarter_m999': 3, 'year_m999': 2024, 'day_of_week_m999': 3, 'day_name_m999': 'Thursday', 'is_weekend_m999': 0, 'is_holiday_m999': 0}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ❌ 导入表 products 失败: (pymysql.err.IntegrityError) (1062, "Duplicate entry '1' for key 'products.PRIMARY'")
# [SQL: INSERT INTO products (product_id, product_name, category, subcategory, brand, price, cost_price, stock_quantity, supplier, rating, review_count, created_date, is_active) VALUES (%(product_id_m0)s, %(product_name_m0)s, %(category_m0)s, %(subcategory_m0)s, %(brand_m0)s, %(price_m0)s, %(cost_price_m0)s, %(stock_quantity_m0)s, %(supplier_m0)s, %(rating_m0)s, %(review_count_m0)s, %(created_date_m0)s, %(is_active_m0)s), (%(product_id_m1)s, %(product_name_m1)s, %(category_m1)s, %(subcategory_m1)s, %(brand_m1)s, %(price_m1)s, %(cost_price_m1)s, %(stock_quantity_m1)s, %(supplier_m1)s, %(rating_m1)s, %(review_count_m1)s, %(created_date_m1)s, %(is_active_m1)s), (%(product_id_m2)s, %(product_name_m2)s, %(category_m2)s, %(subcategory_m2)s, %(brand_m2)s, %(price_m2)s, %(cost_price_m2)s, %(stock_quantity_m2)s, %(supplier_m2)s, %(rating_m2)s, %(review_count_m2)s, %(created_date_m2)s, %(is_active_m2)s), (%(product_id_m3)s, %(product_name_m3)s, %(category_m3)s, %(subcategory_m3)s, %(brand_m3)s, %(price_m3)s, %(cost_price_m3)s, %(stock_quantity_m3)s, %(supplier_m3)s, %(rating_m3)s, %(review_count_m3)s, %(created_date_m3)s, %(is_active_m3)s), (%(product_id_m4)s, %(product_name_m4)s, %(category_m4)s, %(subcategory_m4)s, %(brand_m4)s, %(price_m4)s, %(cost_price_m4)s, %(stock_quantity_m4)s, %(supplier_m4)s, %(rating_m4)s, %(review_count_m4)s, %(created_date_m4)s, %(is_active_m4)s), (%(product_id_m5)s, %(product_name_m5)s, %(category_m5)s, %(subcategory_m5)s, %(brand_m5)s, %(price_m5)s, %(cost_price_m5)s, %(stock_quantity_m5)s, %(supplier_m5)s, %(rating_m5)s, %(review_count_m5)s, %(created_date_m5)s, %(is_active_m5)s), (%(product_id_m6)s, %(product_name_m6)s, %(category_m6)s, %(subcategory_m6)s, %(brand_m6)s, %(price_m6)s, %(cost_price_m6)s, %(stock_quantity_m6)s, %(supplier_m6)s, %(rating_m6)s, %(review_count_m6)s, %(created_date_m6)s, %(is_active_m6)s), (%(product_id_m7)s, %(product_name_m7)s, %(category_m7)s, %(subcategory_m7)s, %(brand_m7)s, %(price_m7)s, %(cost_price_m7)s, %(stock_quantity_m7)s, %(supplier_m7)s, %(rating_m7)s, %(review_count_m7)s, %(created_date_m7)s, %(is_active_m7)s), (%(product_id_m8)s, %(product_name_m8)s, %(category_m8)s, %(subcategory_m8)s, %(brand_m8)s, %(price_m8)s, %(cost_price_m8)s, %(stock_quantity_m8)s, %(supplier_m8)s, %(rating_m8)s, %(review_count_m8)s, %(created_date_m8)s, %(is_active_m8)s), (%(product_id_m9)s, %(product_name_m9)s, %(category_m9)s, %(subcategory_m9)s, %(brand_m9)s, %(price_m9)s, %(cost_price_m9)s, %(stock_quantity_m9)s, %(supplier_m9)s, %(rating_m9)s, %(review_count_m9)s, %(created_date_m9)s, %(is_active_m9)s), (%(product_id_m10)s, %(product_name_m10)s, %(category_m10)s, %(subcategory_m10)s, %(brand_m10)s, %(price_m10)s, %(cost_price_m10)s, %(stock_quantity_m10)s, %(supplier_m10)s, %(rating_m10)s, %(review_count_m10)s, %(created_date_m10)s, %(is_active_m10)s), (%(product_id_m11)s, %(product_name_m11)s, %(category_m11)s, %(subcategory_m11)s, %(brand_m11)s, %(price_m11)s, %(cost_price_m11)s, %(stock_quantity_m11)s, %(supplier_m11)s, %(rating_m11)s, %(review_count_m11)s, %(created_date_m11)s, %(is_active_m11)s), (%(product_id_m12)s, %(product_name_m12)s, %(category_m12)s, %(subcategory_m12)s, %(brand_m12)s, %(price_m12)s, %(cost_price_m12)s, %(stock_quantity_m12)s, %(supplier_m12)s, %(rating_m12)s, %(review_count_m12)s, %(created_date_m12)s, %(is_active_m12)s), (%(product_id_m13)s, %(product_name_m13)s, %(category_m13)s, %(subcategory_m13)s, %(brand_m13)s, %(price_m13)s, %(cost_price_m13)s, %(stock_quantity_m13)s, %(supplier_m13)s, %(rating_m13)s, %(review_count_m13)s, %(created_date_m13)s, %(is_active_m13)s), (%(product_id_m14)s, %(product_name_m14)s, %(category_m14)s, %(subcategory_m14)s, %(brand_m14)s, %(price_m14)s, %(cost_price_m14)s, %(stock_quantity_m14)s, %(supplier_m14)s, %(rating_m14)s, %(review_count_m14)s, %(created_date_m14)s, %(is_active_m14)s), (%(product_id_m15)s, %(product_name_m15)s, %(category_m15)s, %(subcategory_m15)s, %(brand_m15)s, %(price_m15)s, %(cost_price_m15)s, %(sto ...
# [parameters: {'product_id_m0': 1, 'product_name_m0': 'Smartphone Model 1', 'category_m0': 'Electronics', 'subcategory_m0': 'Smartphone', 'brand_m0': np.str_('BrandB'), 'price_m0': 79.63, 'cost_price_m0': 156.31, 'stock_quantity_m0': 27, 'supplier_m0': 'Supplier_11', 'rating_m0': 4.6, 'review_count_m0': 79, 'created_date_m0': datetime.datetime(2021, 2, 7, 0, 0), 'is_active_m0': 1, 'product_id_m1': 2, 'product_name_m1': 'Smartphone Model 2', 'category_m1': 'Electronics', 'subcategory_m1': 'Smartphone', 'brand_m1': np.str_('BrandB'), 'price_m1': 171.41, 'cost_price_m1': 281.77, 'stock_quantity_m1': 509, 'supplier_m1': 'Supplier_3', 'rating_m1': 3.9, 'review_count_m1': 269, 'created_date_m1': datetime.datetime(2021, 2, 23, 0, 0), 'is_active_m1': 0, 'product_id_m2': 3, 'product_name_m2': 'Smartphone Model 3', 'category_m2': 'Electronics', 'subcategory_m2': 'Smartphone', 'brand_m2': np.str_('BrandE'), 'price_m2': 71.08, 'cost_price_m2': 113.74, 'stock_quantity_m2': 606, 'supplier_m2': 'Supplier_18', 'rating_m2': 4.9, 'review_count_m2': 305, 'created_date_m2': datetime.datetime(2022, 9, 29, 0, 0), 'is_active_m2': 1, 'product_id_m3': 4, 'product_name_m3': 'Smartphone Model 4', 'category_m3': 'Electronics', 'subcategory_m3': 'Smartphone', 'brand_m3': np.str_('BrandB'), 'price_m3': 46.34, 'cost_price_m3': 146.72, 'stock_quantity_m3': 797, 'supplier_m3': 'Supplier_6', 'rating_m3': 3.5, 'review_count_m3': 24 ... 2500 parameters truncated ... 'category_m196': 'Sports', 'subcategory_m196': 'Accessories', 'brand_m196': np.str_('BrandA'), 'price_m196': 206.85, 'cost_price_m196': 241.42, 'stock_quantity_m196': 461, 'supplier_m196': 'Supplier_7', 'rating_m196': 3.9, 'review_count_m196': 197, 'created_date_m196': datetime.datetime(2023, 4, 11, 0, 0), 'is_active_m196': 1, 'product_id_m197': 198, 'product_name_m197': 'Accessories Model 198', 'category_m197': 'Sports', 'subcategory_m197': 'Accessories', 'brand_m197': np.str_('BrandB'), 'price_m197': 429.73, 'cost_price_m197': 204.78, 'stock_quantity_m197': 207, 'supplier_m197': 'Supplier_4', 'rating_m197': 4.4, 'review_count_m197': 77, 'created_date_m197': datetime.datetime(2022, 6, 13, 0, 0), 'is_active_m197': 1, 'product_id_m198': 199, 'product_name_m198': 'Accessories Model 199', 'category_m198': 'Sports', 'subcategory_m198': 'Accessories', 'brand_m198': np.str_('BrandC'), 'price_m198': 449.22, 'cost_price_m198': 48.33, 'stock_quantity_m198': 371, 'supplier_m198': 'Supplier_10', 'rating_m198': 4.2, 'review_count_m198': 122, 'created_date_m198': datetime.datetime(2022, 8, 11, 0, 0), 'is_active_m198': 1, 'product_id_m199': 200, 'product_name_m199': 'Accessories Model 200', 'category_m199': 'Sports', 'subcategory_m199': 'Accessories', 'brand_m199': np.str_('BrandB'), 'price_m199': 310.35, 'cost_price_m199': 39.03, 'stock_quantity_m199': 517, 'supplier_m199': 'Supplier_15', 'rating_m199': 4.9, 'review_count_m199': 199, 'created_date_m199': datetime.datetime(2023, 6, 26, 0, 0), 'is_active_m199': 1}]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
# ✅ 成功导入表: customers, 数据量: 5000
# ✅ 成功导入表: orders, 数据量: 50000
# ✅ 成功导入表: behavior_logs, 数据量: 100000
# 🎉 数据导入完成!
